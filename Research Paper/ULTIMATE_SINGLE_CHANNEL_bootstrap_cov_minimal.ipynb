# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng()

# %%
m = 1.0
E_min = 2.05
E_max = 4.2
E_grid = np.linspace(E_min, E_max, 550)
pole_buffer = 2e-3

Ls = np.array([4.0, 5.0, 6.0])
frames = {
    "000": np.array([0, 0, 0], dtype=int),
    "001": np.array([0, 0, 1], dtype=int),
    "011": np.array([0, 1, 1], dtype=int),
    "111": np.array([1, 1, 1], dtype=int),
    "002": np.array([0, 0, 2], dtype=int),
}
frame_names = list(frames.keys())
frame_offsets = dict(zip(frame_names, np.linspace(-0.26, 0.26, len(frame_names))))


def Kinv_true(E):
    E = np.asarray(E, dtype=float)
    return -1 + 1/2*((E/2)**2 - m**2)


_noninteracting_cache = {}


def noninteracting_levels(L, dvec, nmax=5):
    """Two-particle noninteracting E* poles for total momentum 2*pi*dvec/L."""
    dvec = np.asarray(dvec, dtype=int)
    key = (float(L), tuple(int(x) for x in dvec), int(nmax))
    if key in _noninteracting_cache:
        return _noninteracting_cache[key]

    P = 2*np.pi*dvec/L
    poles = []

    ns = range(-nmax, nmax + 1)
    for nx in ns:
        for ny in ns:
            for nz in ns:
                n = np.array([nx, ny, nz], dtype=int)
                p1 = 2*np.pi*n/L
                p2 = 2*np.pi*(dvec - n)/L
                E_lab = np.sqrt(m**2 + np.dot(p1, p1)) + np.sqrt(m**2 + np.dot(p2, p2))
                E_cm_sq = E_lab**2 - np.dot(P, P)
                if E_cm_sq <= 0:
                    continue
                E_cm = np.sqrt(E_cm_sq)
                if E_min - 0.05 < E_cm < E_max + 0.05:
                    poles.append(E_cm)

    poles = np.array(sorted(poles), dtype=float)
    if len(poles) == 0:
        _noninteracting_cache[key] = poles
        return poles

    # Collapse degeneracies so the finite-volume function has one pole per shell.
    unique = [poles[0]]
    for p in poles[1:]:
        if abs(p - unique[-1]) > 1e-5:
            unique.append(p)
    unique = np.array(unique, dtype=float)
    _noninteracting_cache[key] = unique
    return unique


def F_fv(E, L, frame):
    """Toy finite-volume function with the right dependence on L and moving frame."""
    E = np.asarray(E, dtype=float)
    poles = noninteracting_levels(L, frames[frame])
    out = np.zeros_like(E, dtype=float)

    for k, pole in enumerate(poles):
        weight = 0.035/(1 + k)
        out += weight/(E - pole)

    d2 = np.dot(frames[frame], frames[frame])
    return out + 0.04*(E - 2.7) + 0.01*d2*(E - 3.0)


def roots_from_grid(QC, L, frame, min_sep=0.018):
    QC = np.asarray(QC, dtype=float)
    poles = noninteracting_levels(L, frames[frame])

    good = np.isfinite(QC) & (np.abs(QC) < 300.0)
    for pole in poles:
        good &= np.abs(E_grid - pole) > pole_buffer

    # Vectorized zero-crossing search. This is called thousands of times inside the MCMC,
    # so avoiding a Python loop over the full energy grid matters.
    mask = good[:-1] & good[1:] & (QC[:-1]*QC[1:] < 0.0)
    idx = np.where(mask)[0]
    if len(idx) == 0:
        return np.array([], dtype=float)

    E_left = E_grid[idx]
    E_right = E_grid[idx + 1]
    Q_left = QC[idx]
    Q_right = QC[idx + 1]
    candidates = E_left - Q_left*(E_right - E_left)/(Q_right - Q_left)
    candidates = candidates[(E_min < candidates) & (candidates < E_max)]

    roots = []
    for E0 in candidates:
        if np.any(np.abs(E0 - poles) < 1.5*pole_buffer):
            continue
        if all(abs(E0 - old) > min_sep for old in roots):
            roots.append(float(E0))

    return np.array(roots, dtype=float)


def spectrum_from_Kinv(Kinv_function, L, frame):
    return roots_from_grid(Kinv_function(E_grid) + F_fv(E_grid, L, frame), L, frame)

# %%
# Build the exact finite-volume spectrum first.
rows = []

for L in Ls:
    for frame in frame_names:
        E_true_levels = spectrum_from_Kinv(Kinv_true, L, frame)
        for level_index, E_true in enumerate(E_true_levels):
            rows.append({
                "L": float(L),
                "frame": frame,
                "level_index": level_index,
                "E_true": float(E_true),
            })

Etrue = np.array([r["E_true"] for r in rows], dtype=float)
Nlev = len(Etrue)
Nboot = 5

# Same fake covariance model as in the .py file.
sigE_true = np.linspace(0.006, 0.014, Nlev)
rho = 0.55
R = rho**np.abs(np.subtract.outer(np.arange(Nlev), np.arange(Nlev)))
CovE_true = np.outer(sigE_true, sigE_true)*R

# Draw 5000 aligned correlated bootstrap spectra.
Eboot = rng.multivariate_normal(Etrue, CovE_true, size=Nboot)

# Reconstruct the observed central spectrum and covariance from the bootstraps.
# The GP below uses CovE, not CovE_true.
Eobs = np.mean(Eboot, axis=0)
CovE = np.cov(Eboot, rowvar=False, ddof=0)

for i, row in enumerate(rows):
    row["global_index"] = i
    row["E_obs"] = float(Eobs[i])
    row["dE"] = float(np.sqrt(CovE[i, i]))

data = rows

print(f"generated {len(data)} finite-volume levels across {len(Ls)} volumes and {len(frame_names)} frames")
print(f"bootstrap replicas = {Nboot}")
print(f"mean sigma_E from reconstructed CovE = {np.mean(np.sqrt(np.diag(CovE))):.6g}")
print(f"relative Frobenius error = {np.linalg.norm(CovE - CovE_true)/np.linalg.norm(CovE_true):.6g}")

print("Covariance matrices:")

print(CovE_true)
print("")
print(CovE)
# Out:
# generated 46 finite-volume levels across 3 volumes and 5 frames
# bootstrap replicas = 5
# mean sigma_E from reconstructed CovE = 0.00822924
# relative Frobenius error = 1.9747
# Covariance matrices:
# [[3.60000000e-05 2.03866667e-05 1.15353333e-05 ... 5.60664110e-16
#   3.12383049e-16 1.74020460e-16]
#  [2.03866667e-05 3.81649383e-05 2.15947654e-05 ... 1.04959342e-15
#   5.84797896e-16 3.25775677e-16]
#  [1.15353333e-05 2.15947654e-05 4.03930864e-05 ... 1.96326826e-15
#   1.09386657e-15 6.09364575e-16]
#  ...
#  [5.60664110e-16 1.04959342e-15 1.96326826e-15 ... 1.86170864e-04
#   1.03728099e-04 5.77842222e-05]
#  [3.12383049e-16 5.84797896e-16 1.09386657e-15 ... 1.03728099e-04
#   1.91053827e-04 1.06431111e-04]
#  [1.74020460e-16 3.25775677e-16 6.09364575e-16 ... 5.77842222e-05
#   1.06431111e-04 1.96000000e-04]]
#
# [[ 1.91154387e-05 -4.66036902e-06 -3.63788519e-06 ...  1.52423919e-05
#    2.07143936e-05  1.05587757e-05]
#  [-4.66036902e-06  5.17126552e-05  4.67834303e-05 ...  3.47392212e-05
#    1.37304198e-05  4.41666156e-05]
#  [-3.63788519e-06  4.67834303e-05  5.97801436e-05 ...  4.73165548e-05
#   -4.00767916e-07  8.30100030e-05]
#  ...
#  [ 1.52423919e-05  3.47392212e-05  4.73165548e-05 ...  5.61238710e-05
#    1.89662126e-05  8.23111891e-05]
#  [ 2.07143936e-05  1.37304198e-05 -4.00767916e-07 ...  1.89662126e-05
#    3.98750213e-05 -4.16478701e-06]
#  [ 1.05587757e-05  4.41666156e-05  8.30100030e-05 ...  8.23111891e-05
#   -4.16478701e-06  1.53785021e-04]]

# %%
def plot_spectrum(level_rows, title="Finite-volume spectrum", include_observed=True, include_true=True, predicted_rows=None):
    plt.figure(figsize=(10, 6))

    for frame in frame_names:
        offset = frame_offsets[frame]
        rows_frame = [r for r in level_rows if r["frame"] == frame]

        if include_observed:
            x_obs = np.array([r["L"] + offset for r in rows_frame], dtype=float)
            y_obs = np.array([r["E_obs"] for r in rows_frame], dtype=float)
            yerr = np.array([r["dE"] for r in rows_frame], dtype=float)

            plt.errorbar(
                x_obs,
                y_obs,
                yerr=yerr,
                fmt="o",
                markersize=6,
                capsize=5,
                capthick=1.8,
                elinewidth=1.8,
                linewidth=0,
                label=f"{frame} observed",
                zorder=5,
            )

        if include_true:
            x_true = np.array([r["L"] + offset for r in rows_frame], dtype=float)
            y_true = np.array([r["E_true"] for r in rows_frame], dtype=float)

            plt.scatter(
                x_true,
                y_true,
                marker="_",
                s=180,
                linewidths=2.8,
                label=f"{frame} true",
                zorder=4,
            )

    if predicted_rows is not None:
        for frame in frame_names:
            offset = frame_offsets[frame]
            rows_frame = [r for r in predicted_rows if r["frame"] == frame]
            x_pred = np.array([r["L"] + offset for r in rows_frame], dtype=float)
            y_pred = np.array([r["E_pred"] for r in rows_frame], dtype=float)

            plt.scatter(
                x_pred,
                y_pred,
                marker="x",
                s=70,
                linewidths=2.2,
                label=f"{frame} GP",
                zorder=6,
            )

    plt.xticks(Ls, [str(int(L)) for L in Ls])
    plt.xlabel(r"$L$")
    plt.ylabel(r"$E^*$")
    plt.title(title)
    plt.legend(ncols=3, fontsize=8)
    plt.tight_layout()
    plt.show()


plot_spectrum(data, "Finite-volume spectrum")

# %%
n_knots = 7
knots = np.linspace(E_min, E_max, n_knots)

F_grids = {
    (float(L), frame): F_fv(E_grid, L, frame)
    for L in Ls
    for frame in frame_names
}

obs_by_key = {
    (float(L), frame): [r for r in data if r["L"] == float(L) and r["frame"] == frame]
    for L in Ls
    for frame in frame_names
}

# Do not set these exactly to zero.
# sigma=0 collapses the GP covariance.
# l_c=0 causes division by zero in the RBF kernel.
sigma_min, sigma_max = 1e-3, 5.0
lc_min, lc_max = 1e-3, 5.0


def kernel(x, y, sigma, l_c):
    if sigma <= 0 or l_c <= 0:
        raise np.linalg.LinAlgError("sigma and l_c must be positive")

    x = np.asarray(x, dtype=float)
    y = np.asarray(y, dtype=float)

    return sigma**2*np.exp(-0.5*((x[:, None] - y[None, :])/l_c)**2)


def gp_matrices(sigma, l_c):
    C = kernel(knots, knots, sigma, l_c) + 1e-8*np.eye(n_knots)

    sign, logdet = np.linalg.slogdet(C)
    if sign <= 0:
        raise np.linalg.LinAlgError("GP covariance is not positive definite")

    C_inv = np.linalg.inv(C)
    interp_grid = kernel(E_grid, knots, sigma, l_c) @ C_inv

    return C, C_inv, logdet, interp_grid


def predict_levels_from_gp(f_knots, interp_grid, L, frame):
    K_grid = interp_grid @ f_knots
    return roots_from_grid(K_grid + F_grids[(float(L), frame)], L, frame)


def log_likelihood(f_knots, interp_grid, level_penalty=30.0, max_pull=10.0):
    """Correlated Gaussian level likelihood using the reconstructed bootstrap covariance."""
    matched_indices = []
    matched_predictions = []
    penalty = 0.0

    for L in Ls:
        for frame in frame_names:
            obs = obs_by_key[(float(L), frame)]
            E_pred = predict_levels_from_gp(f_knots, interp_grid, L, frame)
            used = np.zeros(len(E_pred), dtype=bool)

            for row in obs:
                E = row["E_obs"]
                sig = row["dE"]

                if len(E_pred) == 0:
                    penalty += 0.5*level_penalty
                    continue

                distances = np.abs(E_pred - E)
                distances[used] = np.inf
                j = np.argmin(distances)
                pull = distances[j]/sig

                if np.isfinite(pull) and pull < max_pull:
                    matched_indices.append(row["global_index"])
                    matched_predictions.append(E_pred[j])
                    used[j] = True
                else:
                    penalty += 0.5*level_penalty

            penalty += 0.5*level_penalty*abs(len(E_pred) - len(obs))

    if len(matched_indices) == 0:
        return float(-penalty)

    matched_indices = np.asarray(matched_indices, dtype=int)
    matched_predictions = np.asarray(matched_predictions, dtype=float)

    residual = matched_predictions - Eobs[matched_indices]
    Cov_sub = CovE[np.ix_(matched_indices, matched_indices)]

    sign, logdet = np.linalg.slogdet(Cov_sub)
    if sign <= 0:
        return -np.inf

    chi2 = residual @ np.linalg.solve(Cov_sub, residual)
    loglike = -0.5*(chi2 + logdet + len(residual)*np.log(2*np.pi))

    return float(loglike - penalty)


def log_hyperprior(sigma, l_c):
    if not (sigma_min <= sigma <= sigma_max and lc_min <= l_c <= lc_max):
        return -np.inf

    # Strictly exclude zero, even if the bounds are accidentally changed.
    if sigma <= 0 or l_c <= 0:
        return -np.inf

    return -np.log(sigma_max - sigma_min) - np.log(lc_max - lc_min)


def log_posterior(f_knots, sigma, l_c):
    # Bayes theorem: log posterior = log likelihood + log GP prior + log hyperprior + constant.
    hp = log_hyperprior(sigma, l_c)
    if not np.isfinite(hp):
        return -np.inf, -np.inf, -np.inf

    try:
        _, C_inv, logdet, interp_grid = gp_matrices(sigma, l_c)
    except np.linalg.LinAlgError:
        return -np.inf, -np.inf, -np.inf
    except FloatingPointError:
        return -np.inf, -np.inf, -np.inf
    except ValueError:
        return -np.inf, -np.inf, -np.inf

    f_knots = np.asarray(f_knots, dtype=float)

    gp_prior = (
        -0.5*f_knots @ C_inv @ f_knots
        -0.5*logdet
        -0.5*n_knots*np.log(2*np.pi)
    )

    logprior = float(gp_prior + hp)
    ll = log_likelihood(f_knots, interp_grid)

    return float(ll + logprior), float(ll), float(logprior)


def Kinv_gp_values(f_knots, sigma, l_c, E):
    E = np.asarray(E, dtype=float)
    _, C_inv, _, _ = gp_matrices(sigma, l_c)
    return kernel(E, knots, sigma, l_c) @ C_inv @ f_knots

# %%
# Parallel-tempered MCMC for p(K^{-1} knots, l_c, sigma | finite-volume levels).
# The beta=1 chain is the real posterior.
# Hot chains have beta<1 and explore more freely.

n_steps = 100000 #10000
burn_in = 500
thin = 5
print_every = 500

# Temperature ladder.
# beta=0 samples GP prior + hyperprior, not literally a flat box in hyperparameters.
betas = np.array([0.0, 0.02, 0.05, 0.10, 0.20, 0.40, 0.70, 1.00])
n_chains = len(betas)

# Function proposal widths.
proposal_width_f_one = 0.10
proposal_width_f_all = 0.06
proposal_width_const = 0.20

# Positive hyperparameter proposals.
# These are random walks in log(sigma), log(l_c).
proposal_width_log_lc = 0.20
proposal_width_log_sigma = 0.20

# Occasional independent GP-prior function refresh.
p_prior_function_refresh = 0.04

# Try swaps every this many steps.
swap_every = 10


def reflect_log_into_box(logx, log_lo, log_hi):
    width = log_hi - log_lo
    if width <= 0:
        raise ValueError("bad log box")

    while logx < log_lo or logx > log_hi:
        if logx < log_lo:
            logx = log_lo + (log_lo - logx)
        if logx > log_hi:
            logx = log_hi - (logx - log_hi)

    return logx


def log_tempered_target(f_knots, sigma, l_c, beta):
    logpost, loglike, logprior = log_posterior(f_knots, sigma, l_c)

    if not np.isfinite(logpost):
        return -np.inf, loglike, logprior

    return beta*loglike + logprior, loglike, logprior


def draw_tame_function():
    """
    Non-cheating function proposal.
    This is not K^{-1} = -F. Re[i/2 * F_complex] 
    It just prevents the chain from starting with a wildly pathological spectrum.
    """
    constant = rng.normal(scale=1.0)
    return constant + 0.25*rng.normal(size=n_knots)


def draw_tame_state():
    sigma = rng.uniform(sigma_min, sigma_max)
    l_c = rng.uniform(lc_min, lc_max)
    f_knots = draw_tame_function()

    return f_knots, sigma, l_c


def draw_function_from_gp_prior(sigma, l_c):
    C, _, _, _ = gp_matrices(sigma, l_c)
    return rng.multivariate_normal(np.zeros(n_knots), C)


# Initialize all chains.
chains_f = []
chains_sigma = []
chains_lc = []
chains_logtarget = []
chains_loglike = []
chains_logprior = []

for c in range(n_chains):
    best = None

    # For each temperature, try a few starts and keep the best tempered target.
    for attempt in range(20):
        f0, sigma0, lc0 = draw_tame_state()
        lt0, ll0, lp0 = log_tempered_target(f0, sigma0, lc0, betas[c])

        if best is None or lt0 > best[0]:
            best = (lt0, ll0, lp0, f0.copy(), sigma0, lc0)

    lt0, ll0, lp0, f0, sigma0, lc0 = best

    chains_f.append(f0.copy())
    chains_sigma.append(sigma0)
    chains_lc.append(lc0)
    chains_logtarget.append(lt0)
    chains_loglike.append(ll0)
    chains_logprior.append(lp0)

chains_f = np.array(chains_f)
chains_sigma = np.array(chains_sigma)
chains_lc = np.array(chains_lc)
chains_logtarget = np.array(chains_logtarget)
chains_loglike = np.array(chains_loglike)
chains_logprior = np.array(chains_logprior)

samples_f = []
samples_sigma = []
samples_lc = []
logpost_samples = []
loglike_samples = []
logprior_samples = []

accepted = np.zeros(n_chains, dtype=int)
proposed = np.zeros(n_chains, dtype=int)

swap_accepted = np.zeros(n_chains - 1, dtype=int)
swap_proposed = np.zeros(n_chains - 1, dtype=int)

best_f = None
best_sigma = None
best_lc = None
best_logpost = -np.inf
best_loglike = -np.inf
best_logprior = -np.inf


for step in range(n_steps):

    # Within-chain Metropolis updates.
    for c in range(n_chains):
        beta = betas[c]

        f_current = chains_f[c].copy()
        sigma_current = chains_sigma[c]
        lc_current = chains_lc[c]
        logtarget_current = chains_logtarget[c]

        f_trial = f_current.copy()
        sigma_trial = sigma_current
        lc_trial = lc_current
        log_q_correction = 0.0

        move = rng.random()

        if move < p_prior_function_refresh:
            # Refresh the function from the GP prior at the current hyperparameters.
            # No hyperparameters move here.
            f_trial = draw_function_from_gp_prior(sigma_trial, lc_trial)

        elif move < 0.40:
            # One-knot local move.
            k = rng.integers(n_knots)
            f_trial[k] += proposal_width_f_one*rng.normal()

        elif move < 0.65:
            # All-knot random walk.
            f_trial += proposal_width_f_all*rng.normal(size=n_knots)

        elif move < 0.80:
            # Vertical shift.
            f_trial += proposal_width_const*rng.normal()

        elif move < 0.90:
            # Multiplicative l_c move.
            log_lc_min = np.log(lc_min)
            log_lc_max = np.log(lc_max)

            log_lc_current = np.log(lc_current)
            log_lc_trial = reflect_log_into_box(
                log_lc_current + proposal_width_log_lc*rng.normal(),
                log_lc_min,
                log_lc_max,
            )

            lc_trial = np.exp(log_lc_trial)

            # Hastings correction for proposing symmetrically in log(l_c)
            # while targeting a density uniform in l_c.
            log_q_correction = np.log(lc_trial) - np.log(lc_current)

        else:
            # Multiplicative sigma move.
            log_sigma_min = np.log(sigma_min)
            log_sigma_max = np.log(sigma_max)

            log_sigma_current = np.log(sigma_current)
            log_sigma_trial = reflect_log_into_box(
                log_sigma_current + proposal_width_log_sigma*rng.normal(),
                log_sigma_min,
                log_sigma_max,
            )

            sigma_trial = np.exp(log_sigma_trial)

            # Hastings correction for proposing symmetrically in log(sigma)
            # while targeting a density uniform in sigma.
            log_q_correction = np.log(sigma_trial) - np.log(sigma_current)

        logtarget_trial, loglike_trial, logprior_trial = log_tempered_target(
            f_trial,
            sigma_trial,
            lc_trial,
            beta,
        )

        proposed[c] += 1

        if np.log(rng.random()) < logtarget_trial - logtarget_current + log_q_correction:
            chains_f[c] = f_trial.copy()
            chains_sigma[c] = sigma_trial
            chains_lc[c] = lc_trial
            chains_logtarget[c] = logtarget_trial
            chains_loglike[c] = loglike_trial
            chains_logprior[c] = logprior_trial
            accepted[c] += 1

    # Parallel-tempering swaps.
    if (step + 1) % swap_every == 0:
        for c in range(n_chains - 1):
            beta_a = betas[c]
            beta_b = betas[c + 1]

            ll_a = chains_loglike[c]
            ll_b = chains_loglike[c + 1]

            # Priors cancel in the swap ratio because both chains use the same prior.
            log_swap_ratio = (beta_a - beta_b)*(ll_b - ll_a)

            swap_proposed[c] += 1

            if np.log(rng.random()) < log_swap_ratio:
                chains_f[[c, c + 1]] = chains_f[[c + 1, c]]
                chains_sigma[[c, c + 1]] = chains_sigma[[c + 1, c]]
                chains_lc[[c, c + 1]] = chains_lc[[c + 1, c]]
                chains_loglike[[c, c + 1]] = chains_loglike[[c + 1, c]]
                chains_logprior[[c, c + 1]] = chains_logprior[[c + 1, c]]

                chains_logtarget[c] = betas[c]*chains_loglike[c] + chains_logprior[c]
                chains_logtarget[c + 1] = betas[c + 1]*chains_loglike[c + 1] + chains_logprior[c + 1]

                swap_accepted[c] += 1

    # The beta=1 chain is the final chain.
    cold = n_chains - 1

    cold_logpost, cold_loglike, cold_logprior = log_posterior(
        chains_f[cold],
        chains_sigma[cold],
        chains_lc[cold],
    )

    if cold_logpost > best_logpost:
        best_f = chains_f[cold].copy()
        best_sigma = chains_sigma[cold]
        best_lc = chains_lc[cold]
        best_logpost = cold_logpost
        best_loglike = cold_loglike
        best_logprior = cold_logprior

    if step >= burn_in and step % thin == 0:
        samples_f.append(chains_f[cold].copy())
        samples_sigma.append(chains_sigma[cold])
        samples_lc.append(chains_lc[cold])
        logpost_samples.append(cold_logpost)
        loglike_samples.append(cold_loglike)
        logprior_samples.append(cold_logprior)

    if print_every and (step + 1) % print_every == 0:
        acc_rates = accepted/np.maximum(proposed, 1)
        swap_rates = swap_accepted/np.maximum(swap_proposed, 1)

        print(f"step {step + 1}/{n_steps}")
        print(
            "  chain acceptance:",
            " ".join([f"b={betas[i]:.2g}:{acc_rates[i]:.2f}" for i in range(n_chains)])
        )
        print(
            "  swap acceptance:",
            " ".join([f"{i}-{i+1}:{swap_rates[i]:.2f}" for i in range(n_chains - 1)])
        )
        print(
            f"  cold current: log posterior={cold_logpost:.3f}, "
            f"log likelihood={cold_loglike:.3f}, log prior={cold_logprior:.3f}, "
            f"sigma={chains_sigma[cold]:.3g}, l_c={chains_lc[cold]:.3g}"
        )
        print(
            f"  MAP: log posterior={best_logpost:.3f}, "
            f"log likelihood={best_loglike:.3f}, log prior={best_logprior:.3f}, "
            f"sigma={best_sigma:.3g}, l_c={best_lc:.3g}"
        )

samples_f = np.array(samples_f)
samples_sigma = np.array(samples_sigma)
samples_lc = np.array(samples_lc)
logpost_samples = np.array(logpost_samples)
loglike_samples = np.array(loglike_samples)
logprior_samples = np.array(logprior_samples)

print("done")
print(f"saved posterior samples = {len(samples_f)}")
print(
    f"MAP: sigma={best_sigma:.6g}, l_c={best_lc:.6g}, "
    f"log posterior={best_logpost:.3f}, "
    f"log likelihood={best_loglike:.3f}, log prior={best_logprior:.3f}"
)

print("final chain acceptance rates:")
for i in range(n_chains):
    print(f"  beta={betas[i]:.3g}: {accepted[i]/max(proposed[i], 1):.3f}")

print("final swap acceptance rates:")
for i in range(n_chains - 1):
    print(f"  beta {betas[i]:.3g} <-> {betas[i+1]:.3g}: {swap_accepted[i]/max(swap_proposed[i], 1):.3f}")
# Out:
# step 500/100000
#   chain acceptance: b=0:0.83 b=0.02:0.72 b=0.05:0.47 b=0.1:0.42 b=0.2:0.33 b=0.4:0.25 b=0.7:0.23 b=1:0.24
#   swap acceptance: 0-1:0.24 1-2:0.18 2-3:0.44 3-4:0.30 4-5:0.12 5-6:0.06 6-7:0.10
#   cold current: log posterior=177.800, log likelihood=171.640, log prior=6.160, sigma=0.754, l_c=1.02
#   MAP: log posterior=177.926, log likelihood=173.646, log prior=4.280, sigma=0.841, l_c=0.959
# step 1000/100000
#   chain acceptance: b=0:0.78 b=0.02:0.69 b=0.05:0.44 b=0.1:0.38 b=0.2:0.30 b=0.4:0.23 b=0.7:0.22 b=1:0.20
#   swap acceptance: 0-1:0.14 1-2:0.16 2-3:0.36 3-4:0.20 4-5:0.08 5-6:0.21 6-7:0.44
#   cold current: log posterior=179.826, log likelihood=177.106, log prior=2.720, sigma=1.53, l_c=1.1
#   MAP: log posterior=187.859, log likelihood=176.011, log prior=11.847, sigma=0.699, l_c=1.46
# step 1500/100000
#   chain acceptance: b=0:0.77 b=0.02:0.58 b=0.05:0.38 b=0.1:0.34 b=0.2:0.29 b=0.4:0.21 b=0.7:0.19 b=1:0.19
#   swap acceptance: 0-1:0.09 1-2:0.21 2-3:0.35 3-4:0.16 4-5:0.09 5-6:0.25 6-7:0.57
#   cold current: log posterior=176.552, log likelihood=177.484, log prior=-0.932, sigma=2.29, l_c=0.997
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 2000/100000
#   chain acceptance: b=0:0.73 b=0.02:0.53 b=0.05:0.34 b=0.1:0.30 b=0.2:0.28 b=0.4:0.20 b=0.7:0.18 b=1:0.19
#   swap acceptance: 0-1:0.07 1-2:0.27 2-3:0.38 3-4:0.12 4-5:0.17 5-6:0.25 6-7:0.56
#   cold current: log posterior=186.803, log likelihood=175.850, log prior=10.954, sigma=0.805, l_c=1.65
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 2500/100000
#   chain acceptance: b=0:0.71 b=0.02:0.50 b=0.05:0.31 b=0.1:0.28 b=0.2:0.26 b=0.4:0.18 b=0.7:0.18 b=1:0.18
#   swap acceptance: 0-1:0.06 1-2:0.23 2-3:0.34 3-4:0.13 4-5:0.19 5-6:0.29 6-7:0.58
#   cold current: log posterior=187.982, log likelihood=175.668, log prior=12.315, sigma=1.36, l_c=2
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 3000/100000
#   chain acceptance: b=0:0.67 b=0.02:0.46 b=0.05:0.29 b=0.1:0.28 b=0.2:0.25 b=0.4:0.18 b=0.7:0.17 b=1:0.17
#   swap acceptance: 0-1:0.05 1-2:0.30 2-3:0.31 3-4:0.19 4-5:0.20 5-6:0.31 6-7:0.60
#   cold current: log posterior=188.139, log likelihood=175.677, log prior=12.461, sigma=1.56, l_c=1.99
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 3500/100000
#   chain acceptance: b=0:0.60 b=0.02:0.43 b=0.05:0.28 b=0.1:0.27 b=0.2:0.24 b=0.4:0.18 b=0.7:0.17 b=1:0.17
#   swap acceptance: 0-1:0.04 1-2:0.31 2-3:0.29 3-4:0.26 4-5:0.22 5-6:0.35 6-7:0.63
#   cold current: log posterior=182.102, log likelihood=175.066, log prior=7.036, sigma=1.2, l_c=1.36
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 4000/100000
#   chain acceptance: b=0:0.55 b=0.02:0.40 b=0.05:0.26 b=0.1:0.26 b=0.2:0.24 b=0.4:0.17 b=0.7:0.17 b=1:0.16
#   swap acceptance: 0-1:0.04 1-2:0.31 2-3:0.30 3-4:0.29 4-5:0.25 5-6:0.37 6-7:0.65
#   cold current: log posterior=181.029, log likelihood=175.238, log prior=5.791, sigma=0.909, l_c=1.13
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 4500/100000
#   chain acceptance: b=0:0.51 b=0.02:0.36 b=0.05:0.26 b=0.1:0.25 b=0.2:0.23 b=0.4:0.17 b=0.7:0.16 b=1:0.16
#   swap acceptance: 0-1:0.03 1-2:0.30 2-3:0.33 3-4:0.32 4-5:0.26 5-6:0.40 6-7:0.63
#   cold current: log posterior=182.688, log likelihood=172.629, log prior=10.059, sigma=3.23, l_c=2.23
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 5000/100000
#   chain acceptance: b=0:0.48 b=0.02:0.34 b=0.05:0.26 b=0.1:0.24 b=0.2:0.22 b=0.4:0.17 b=0.7:0.16 b=1:0.16
#   swap acceptance: 0-1:0.03 1-2:0.32 2-3:0.32 3-4:0.37 4-5:0.27 5-6:0.41 6-7:0.63
#   cold current: log posterior=187.287, log likelihood=175.424, log prior=11.863, sigma=1.67, l_c=2.04
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 5500/100000
#   chain acceptance: b=0:0.45 b=0.02:0.33 b=0.05:0.25 b=0.1:0.23 b=0.2:0.22 b=0.4:0.16 b=0.7:0.16 b=1:0.16
#   swap acceptance: 0-1:0.03 1-2:0.31 2-3:0.35 3-4:0.40 4-5:0.27 5-6:0.41 6-7:0.65
#   cold current: log posterior=182.730, log likelihood=175.713, log prior=7.017, sigma=1.48, l_c=1.67
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 6000/100000
#   chain acceptance: b=0:0.42 b=0.02:0.31 b=0.05:0.24 b=0.1:0.23 b=0.2:0.21 b=0.4:0.16 b=0.7:0.16 b=1:0.16
#   swap acceptance: 0-1:0.02 1-2:0.30 2-3:0.35 3-4:0.41 4-5:0.28 5-6:0.42 6-7:0.64
#   cold current: log posterior=182.040, log likelihood=176.221, log prior=5.819, sigma=2.62, l_c=1.63
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 6500/100000
#   chain acceptance: b=0:0.40 b=0.02:0.30 b=0.05:0.24 b=0.1:0.22 b=0.2:0.21 b=0.4:0.16 b=0.7:0.16 b=1:0.15
#   swap acceptance: 0-1:0.02 1-2:0.29 2-3:0.37 3-4:0.43 4-5:0.29 5-6:0.43 6-7:0.64
#   cold current: log posterior=186.292, log likelihood=174.535, log prior=11.757, sigma=1.96, l_c=2.32
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 7000/100000
#   chain acceptance: b=0:0.39 b=0.02:0.29 b=0.05:0.23 b=0.1:0.21 b=0.2:0.21 b=0.4:0.16 b=0.7:0.16 b=1:0.15
#   swap acceptance: 0-1:0.02 1-2:0.28 2-3:0.40 3-4:0.42 4-5:0.29 5-6:0.44 6-7:0.65
#   cold current: log posterior=175.512, log likelihood=173.601, log prior=1.911, sigma=1.57, l_c=1.15
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 7500/100000
#   chain acceptance: b=0:0.38 b=0.02:0.28 b=0.05:0.23 b=0.1:0.21 b=0.2:0.20 b=0.4:0.16 b=0.7:0.16 b=1:0.15
#   swap acceptance: 0-1:0.02 1-2:0.27 2-3:0.42 3-4:0.43 4-5:0.30 5-6:0.44 6-7:0.66
#   cold current: log posterior=187.788, log likelihood=176.137, log prior=11.651, sigma=0.497, l_c=1.36
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 8000/100000
#   chain acceptance: b=0:0.37 b=0.02:0.27 b=0.05:0.22 b=0.1:0.21 b=0.2:0.20 b=0.4:0.16 b=0.7:0.16 b=1:0.15
#   swap acceptance: 0-1:0.02 1-2:0.27 2-3:0.42 3-4:0.44 4-5:0.31 5-6:0.45 6-7:0.67
#   cold current: log posterior=184.327, log likelihood=175.413, log prior=8.913, sigma=0.723, l_c=1.28
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 8500/100000
#   chain acceptance: b=0:0.36 b=0.02:0.27 b=0.05:0.22 b=0.1:0.20 b=0.2:0.19 b=0.4:0.16 b=0.7:0.16 b=1:0.15
#   swap acceptance: 0-1:0.02 1-2:0.25 2-3:0.43 3-4:0.44 4-5:0.33 5-6:0.44 6-7:0.67
#   cold current: log posterior=183.519, log likelihood=175.442, log prior=8.077, sigma=2.55, l_c=1.8
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 9000/100000
#   chain acceptance: b=0:0.35 b=0.02:0.26 b=0.05:0.21 b=0.1:0.20 b=0.2:0.19 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.02 1-2:0.25 2-3:0.42 3-4:0.45 4-5:0.34 5-6:0.45 6-7:0.67
#   cold current: log posterior=176.899, log likelihood=176.343, log prior=0.556, sigma=2, l_c=1.14
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 9500/100000
#   chain acceptance: b=0:0.34 b=0.02:0.26 b=0.05:0.21 b=0.1:0.20 b=0.2:0.19 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.26 2-3:0.41 3-4:0.46 4-5:0.35 5-6:0.45 6-7:0.67
#   cold current: log posterior=186.077, log likelihood=176.209, log prior=9.868, sigma=2.29, l_c=2.23
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 10000/100000
#   chain acceptance: b=0:0.33 b=0.02:0.25 b=0.05:0.21 b=0.1:0.19 b=0.2:0.18 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.28 2-3:0.39 3-4:0.47 4-5:0.36 5-6:0.44 6-7:0.68
#   cold current: log posterior=184.862, log likelihood=176.224, log prior=8.638, sigma=4.32, l_c=2.24
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 10500/100000
#   chain acceptance: b=0:0.32 b=0.02:0.25 b=0.05:0.20 b=0.1:0.19 b=0.2:0.18 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.27 2-3:0.41 3-4:0.47 4-5:0.37 5-6:0.44 6-7:0.68
#   cold current: log posterior=177.865, log likelihood=175.841, log prior=2.023, sigma=1.67, l_c=1.32
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 11000/100000
#   chain acceptance: b=0:0.32 b=0.02:0.24 b=0.05:0.20 b=0.1:0.19 b=0.2:0.18 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.27 2-3:0.42 3-4:0.48 4-5:0.38 5-6:0.43 6-7:0.69
#   cold current: log posterior=180.974, log likelihood=175.993, log prior=4.980, sigma=0.957, l_c=1.34
#   MAP: log posterior=188.807, log likelihood=176.153, log prior=12.654, sigma=1.1, l_c=1.93
# step 11500/100000
#   chain acceptance: b=0:0.31 b=0.02:0.24 b=0.05:0.20 b=0.1:0.19 b=0.2:0.18 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.26 2-3:0.44 3-4:0.49 4-5:0.38 5-6:0.41 6-7:0.70
#   cold current: log posterior=179.657, log likelihood=176.952, log prior=2.706, sigma=2.07, l_c=1.24
#   MAP: log posterior=189.091, log likelihood=176.308, log prior=12.783, sigma=1.24, l_c=1.91
# step 12000/100000
#   chain acceptance: b=0:0.31 b=0.02:0.23 b=0.05:0.20 b=0.1:0.19 b=0.2:0.18 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.27 2-3:0.43 3-4:0.49 4-5:0.40 5-6:0.41 6-7:0.70
#   cold current: log posterior=182.808, log likelihood=176.706, log prior=6.102, sigma=2.1, l_c=1.57
#   MAP: log posterior=189.274, log likelihood=176.308, log prior=12.966, sigma=1.02, l_c=1.88
# step 12500/100000
#   chain acceptance: b=0:0.30 b=0.02:0.23 b=0.05:0.20 b=0.1:0.18 b=0.2:0.18 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.27 2-3:0.43 3-4:0.50 4-5:0.40 5-6:0.40 6-7:0.71
#   cold current: log posterior=187.945, log likelihood=175.525, log prior=12.420, sigma=1.56, l_c=2.05
#   MAP: log posterior=189.274, log likelihood=176.308, log prior=12.966, sigma=1.02, l_c=1.88
# step 13000/100000
#   chain acceptance: b=0:0.30 b=0.02:0.23 b=0.05:0.19 b=0.1:0.18 b=0.2:0.17 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.27 2-3:0.42 3-4:0.50 4-5:0.41 5-6:0.40 6-7:0.70
#   cold current: log posterior=182.407, log likelihood=175.673, log prior=6.734, sigma=3.83, l_c=2.21
#   MAP: log posterior=189.274, log likelihood=176.308, log prior=12.966, sigma=1.02, l_c=1.88
# step 13500/100000
#   chain acceptance: b=0:0.30 b=0.02:0.23 b=0.05:0.19 b=0.1:0.18 b=0.2:0.17 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.26 2-3:0.43 3-4:0.51 4-5:0.41 5-6:0.40 6-7:0.69
#   cold current: log posterior=183.188, log likelihood=177.666, log prior=5.522, sigma=4.39, l_c=2.08
#   MAP: log posterior=189.274, log likelihood=176.308, log prior=12.966, sigma=1.02, l_c=1.88
# step 14000/100000
#   chain acceptance: b=0:0.29 b=0.02:0.22 b=0.05:0.19 b=0.1:0.18 b=0.2:0.17 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.26 2-3:0.44 3-4:0.51 4-5:0.41 5-6:0.41 6-7:0.68
#   cold current: log posterior=179.294, log likelihood=177.593, log prior=1.702, sigma=3.46, l_c=1.81
#   MAP: log posterior=189.274, log likelihood=176.308, log prior=12.966, sigma=1.02, l_c=1.88
# step 14500/100000
#   chain acceptance: b=0:0.29 b=0.02:0.23 b=0.05:0.19 b=0.1:0.18 b=0.2:0.17 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.25 2-3:0.46 3-4:0.50 4-5:0.42 5-6:0.42 6-7:0.67
#   cold current: log posterior=179.588, log likelihood=177.664, log prior=1.923, sigma=1.89, l_c=1.11
#   MAP: log posterior=189.274, log likelihood=176.308, log prior=12.966, sigma=1.02, l_c=1.88
# step 15000/100000
#   chain acceptance: b=0:0.29 b=0.02:0.23 b=0.05:0.19 b=0.1:0.18 b=0.2:0.17 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.24 2-3:0.47 3-4:0.50 4-5:0.42 5-6:0.43 6-7:0.67
#   cold current: log posterior=182.194, log likelihood=177.372, log prior=4.822, sigma=0.894, l_c=1.24
#   MAP: log posterior=189.274, log likelihood=176.308, log prior=12.966, sigma=1.02, l_c=1.88
# step 15500/100000
#   chain acceptance: b=0:0.28 b=0.02:0.23 b=0.05:0.19 b=0.1:0.18 b=0.2:0.17 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.23 2-3:0.48 3-4:0.50 4-5:0.42 5-6:0.43 6-7:0.67
#   cold current: log posterior=182.234, log likelihood=177.616, log prior=4.618, sigma=0.826, l_c=0.995
#   MAP: log posterior=189.274, log likelihood=176.308, log prior=12.966, sigma=1.02, l_c=1.88
# step 16000/100000
#   chain acceptance: b=0:0.28 b=0.02:0.24 b=0.05:0.19 b=0.1:0.18 b=0.2:0.17 b=0.4:0.15 b=0.7:0.15 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.22 2-3:0.48 3-4:0.50 4-5:0.42 5-6:0.44 6-7:0.67
#   cold current: log posterior=176.575, log likelihood=174.024, log prior=2.550, sigma=3.91, l_c=1.53
#   MAP: log posterior=189.274, log likelihood=176.308, log prior=12.966, sigma=1.02, l_c=1.88
# step 16500/100000
#   chain acceptance: b=0:0.28 b=0.02:0.24 b=0.05:0.19 b=0.1:0.18 b=0.2:0.16 b=0.4:0.15 b=0.7:0.15 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.22 2-3:0.49 3-4:0.50 4-5:0.42 5-6:0.43 6-7:0.67
#   cold current: log posterior=179.040, log likelihood=177.131, log prior=1.909, sigma=0.578, l_c=0.804
#   MAP: log posterior=189.274, log likelihood=176.308, log prior=12.966, sigma=1.02, l_c=1.88
# step 17000/100000
#   chain acceptance: b=0:0.28 b=0.02:0.24 b=0.05:0.19 b=0.1:0.18 b=0.2:0.16 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.21 2-3:0.48 3-4:0.50 4-5:0.42 5-6:0.43 6-7:0.66
#   cold current: log posterior=177.097, log likelihood=177.997, log prior=-0.900, sigma=0.899, l_c=0.726
#   MAP: log posterior=189.274, log likelihood=176.308, log prior=12.966, sigma=1.02, l_c=1.88
# step 17500/100000
#   chain acceptance: b=0:0.27 b=0.02:0.25 b=0.05:0.19 b=0.1:0.17 b=0.2:0.16 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.21 2-3:0.48 3-4:0.51 4-5:0.42 5-6:0.43 6-7:0.65
#   cold current: log posterior=182.115, log likelihood=174.956, log prior=7.159, sigma=4.01, l_c=2.06
#   MAP: log posterior=189.274, log likelihood=176.308, log prior=12.966, sigma=1.02, l_c=1.88
# step 18000/100000
#   chain acceptance: b=0:0.27 b=0.02:0.25 b=0.05:0.19 b=0.1:0.18 b=0.2:0.16 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.20 2-3:0.48 3-4:0.52 4-5:0.42 5-6:0.44 6-7:0.65
#   cold current: log posterior=184.366, log likelihood=177.029, log prior=7.338, sigma=0.798, l_c=1.33
#   MAP: log posterior=189.274, log likelihood=176.308, log prior=12.966, sigma=1.02, l_c=1.88
# step 18500/100000
#   chain acceptance: b=0:0.27 b=0.02:0.25 b=0.05:0.19 b=0.1:0.17 b=0.2:0.16 b=0.4:0.15 b=0.7:0.15 b=1:0.15
#   swap acceptance: 0-1:0.01 1-2:0.20 2-3:0.48 3-4:0.52 4-5:0.43 5-6:0.45 6-7:0.65
#   cold current: log posterior=184.049, log likelihood=176.995, log prior=7.054, sigma=0.763, l_c=1.24
#   MAP: log posterior=189.274, log likelihood=176.308, log prior=12.966, sigma=1.02, l_c=1.88
# step 19000/100000
#   chain acceptance: b=0:0.27 b=0.02:0.25 b=0.05:0.19 b=0.1:0.17 b=0.2:0.16 b=0.4:0.15 b=0.7:0.15 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.20 2-3:0.48 3-4:0.51 4-5:0.43 5-6:0.45 6-7:0.65
#   cold current: log posterior=187.152, log likelihood=176.312, log prior=10.839, sigma=3.04, l_c=2.45
#   MAP: log posterior=189.565, log likelihood=176.060, log prior=13.505, sigma=1.57, l_c=2.22
# step 19500/100000
#   chain acceptance: b=0:0.27 b=0.02:0.25 b=0.05:0.19 b=0.1:0.17 b=0.2:0.16 b=0.4:0.15 b=0.7:0.15 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.19 2-3:0.48 3-4:0.51 4-5:0.44 5-6:0.46 6-7:0.65
#   cold current: log posterior=184.610, log likelihood=177.520, log prior=7.090, sigma=0.759, l_c=1.18
#   MAP: log posterior=189.565, log likelihood=176.060, log prior=13.505, sigma=1.57, l_c=2.22
# step 20000/100000
#   chain acceptance: b=0:0.26 b=0.02:0.25 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.15 b=0.7:0.15 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.19 2-3:0.49 3-4:0.52 4-5:0.44 5-6:0.46 6-7:0.65
#   cold current: log posterior=184.263, log likelihood=173.947, log prior=10.317, sigma=2.37, l_c=2.16
#   MAP: log posterior=190.259, log likelihood=176.309, log prior=13.950, sigma=0.983, l_c=2.01
# step 20500/100000
#   chain acceptance: b=0:0.26 b=0.02:0.25 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.15 b=0.7:0.15 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.18 2-3:0.50 3-4:0.52 4-5:0.44 5-6:0.46 6-7:0.65
#   cold current: log posterior=184.388, log likelihood=177.952, log prior=6.436, sigma=1.98, l_c=1.94
#   MAP: log posterior=190.259, log likelihood=176.309, log prior=13.950, sigma=0.983, l_c=2.01
# step 21000/100000
#   chain acceptance: b=0:0.26 b=0.02:0.25 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.15 b=0.7:0.15 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.18 2-3:0.51 3-4:0.52 4-5:0.44 5-6:0.46 6-7:0.65
#   cold current: log posterior=183.625, log likelihood=176.192, log prior=7.433, sigma=2.84, l_c=1.87
#   MAP: log posterior=190.259, log likelihood=176.309, log prior=13.950, sigma=0.983, l_c=2.01
# step 21500/100000
#   chain acceptance: b=0:0.26 b=0.02:0.25 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.15 b=0.7:0.15 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.18 2-3:0.51 3-4:0.52 4-5:0.44 5-6:0.47 6-7:0.64
#   cold current: log posterior=184.629, log likelihood=177.345, log prior=7.284, sigma=2.79, l_c=1.77
#   MAP: log posterior=190.259, log likelihood=176.309, log prior=13.950, sigma=0.983, l_c=2.01
# step 22000/100000
#   chain acceptance: b=0:0.26 b=0.02:0.24 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.15 b=0.7:0.15 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.18 2-3:0.51 3-4:0.52 4-5:0.44 5-6:0.47 6-7:0.63
#   cold current: log posterior=187.079, log likelihood=173.512, log prior=13.567, sigma=1.2, l_c=2.13
#   MAP: log posterior=190.259, log likelihood=176.309, log prior=13.950, sigma=0.983, l_c=2.01
# step 22500/100000
#   chain acceptance: b=0:0.26 b=0.02:0.24 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.15 b=0.7:0.15 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.18 2-3:0.51 3-4:0.52 4-5:0.44 5-6:0.47 6-7:0.63
#   cold current: log posterior=184.756, log likelihood=177.350, log prior=7.407, sigma=3.21, l_c=1.9
#   MAP: log posterior=190.259, log likelihood=176.309, log prior=13.950, sigma=0.983, l_c=2.01
# step 23000/100000
#   chain acceptance: b=0:0.25 b=0.02:0.24 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.15 b=0.7:0.15 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.18 2-3:0.51 3-4:0.52 4-5:0.43 5-6:0.47 6-7:0.63
#   cold current: log posterior=184.347, log likelihood=176.189, log prior=8.158, sigma=2.23, l_c=1.76
#   MAP: log posterior=190.259, log likelihood=176.309, log prior=13.950, sigma=0.983, l_c=2.01
# step 23500/100000
#   chain acceptance: b=0:0.25 b=0.02:0.24 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.15 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.18 2-3:0.50 3-4:0.52 4-5:0.43 5-6:0.47 6-7:0.63
#   cold current: log posterior=185.480, log likelihood=178.478, log prior=7.002, sigma=1.43, l_c=1.39
#   MAP: log posterior=190.259, log likelihood=176.309, log prior=13.950, sigma=0.983, l_c=2.01
# step 24000/100000
#   chain acceptance: b=0:0.25 b=0.02:0.24 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.15 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.17 2-3:0.50 3-4:0.53 4-5:0.43 5-6:0.47 6-7:0.63
#   cold current: log posterior=174.914, log likelihood=174.038, log prior=0.876, sigma=1.03, l_c=0.869
#   MAP: log posterior=190.259, log likelihood=176.309, log prior=13.950, sigma=0.983, l_c=2.01
# step 24500/100000
#   chain acceptance: b=0:0.25 b=0.02:0.24 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.17 2-3:0.50 3-4:0.53 4-5:0.42 5-6:0.47 6-7:0.62
#   cold current: log posterior=187.170, log likelihood=178.639, log prior=8.531, sigma=1.06, l_c=1.56
#   MAP: log posterior=190.259, log likelihood=176.309, log prior=13.950, sigma=0.983, l_c=2.01
# step 25000/100000
#   chain acceptance: b=0:0.25 b=0.02:0.24 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.17 2-3:0.51 3-4:0.53 4-5:0.41 5-6:0.47 6-7:0.63
#   cold current: log posterior=189.862, log likelihood=176.187, log prior=13.675, sigma=1.16, l_c=2.02
#   MAP: log posterior=190.293, log likelihood=176.188, log prior=14.105, sigma=0.717, l_c=1.81
# step 25500/100000
#   chain acceptance: b=0:0.25 b=0.02:0.24 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.17 2-3:0.51 3-4:0.53 4-5:0.41 5-6:0.48 6-7:0.63
#   cold current: log posterior=186.096, log likelihood=178.519, log prior=7.578, sigma=0.869, l_c=1.33
#   MAP: log posterior=190.293, log likelihood=176.188, log prior=14.105, sigma=0.717, l_c=1.81
# step 26000/100000
#   chain acceptance: b=0:0.24 b=0.02:0.23 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.16 2-3:0.51 3-4:0.54 4-5:0.41 5-6:0.48 6-7:0.63
#   cold current: log posterior=190.576, log likelihood=176.434, log prior=14.142, sigma=0.641, l_c=1.73
#   MAP: log posterior=190.576, log likelihood=176.434, log prior=14.142, sigma=0.641, l_c=1.73
# step 26500/100000
#   chain acceptance: b=0:0.24 b=0.02:0.23 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.16 2-3:0.51 3-4:0.54 4-5:0.41 5-6:0.48 6-7:0.62
#   cold current: log posterior=182.716, log likelihood=174.976, log prior=7.740, sigma=3.47, l_c=2.07
#   MAP: log posterior=190.576, log likelihood=176.434, log prior=14.142, sigma=0.641, l_c=1.73
# step 27000/100000
#   chain acceptance: b=0:0.24 b=0.02:0.23 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.16 2-3:0.52 3-4:0.54 4-5:0.41 5-6:0.48 6-7:0.62
#   cold current: log posterior=188.089, log likelihood=178.053, log prior=10.035, sigma=0.939, l_c=1.58
#   MAP: log posterior=190.576, log likelihood=176.434, log prior=14.142, sigma=0.641, l_c=1.73
# step 27500/100000
#   chain acceptance: b=0:0.24 b=0.02:0.23 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.16 2-3:0.53 3-4:0.55 4-5:0.40 5-6:0.48 6-7:0.62
#   cold current: log posterior=176.616, log likelihood=173.918, log prior=2.698, sigma=0.491, l_c=0.927
#   MAP: log posterior=190.731, log likelihood=176.377, log prior=14.354, sigma=0.669, l_c=1.71
# step 28000/100000
#   chain acceptance: b=0:0.24 b=0.02:0.23 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.01 1-2:0.16 2-3:0.53 3-4:0.55 4-5:0.40 5-6:0.48 6-7:0.62
#   cold current: log posterior=187.600, log likelihood=177.911, log prior=9.688, sigma=2.44, l_c=2.2
#   MAP: log posterior=190.731, log likelihood=176.377, log prior=14.354, sigma=0.669, l_c=1.71
# step 28500/100000
#   chain acceptance: b=0:0.24 b=0.02:0.23 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.15 2-3:0.53 3-4:0.55 4-5:0.41 5-6:0.47 6-7:0.63
#   cold current: log posterior=185.144, log likelihood=177.479, log prior=7.665, sigma=3.39, l_c=2.3
#   MAP: log posterior=190.731, log likelihood=176.377, log prior=14.354, sigma=0.669, l_c=1.71
# step 29000/100000
#   chain acceptance: b=0:0.24 b=0.02:0.23 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.15 2-3:0.53 3-4:0.55 4-5:0.41 5-6:0.46 6-7:0.63
#   cold current: log posterior=185.212, log likelihood=177.437, log prior=7.774, sigma=2.21, l_c=1.78
#   MAP: log posterior=190.731, log likelihood=176.377, log prior=14.354, sigma=0.669, l_c=1.71
# step 29500/100000
#   chain acceptance: b=0:0.24 b=0.02:0.22 b=0.05:0.18 b=0.1:0.17 b=0.2:0.16 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.15 2-3:0.53 3-4:0.55 4-5:0.41 5-6:0.46 6-7:0.63
#   cold current: log posterior=185.882, log likelihood=177.514, log prior=8.368, sigma=3.49, l_c=2.29
#   MAP: log posterior=190.731, log likelihood=176.377, log prior=14.354, sigma=0.669, l_c=1.71
# step 30000/100000
#   chain acceptance: b=0:0.24 b=0.02:0.22 b=0.05:0.18 b=0.1:0.16 b=0.2:0.16 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.15 2-3:0.54 3-4:0.55 4-5:0.42 5-6:0.45 6-7:0.63
#   cold current: log posterior=186.428, log likelihood=177.456, log prior=8.972, sigma=2.09, l_c=1.98
#   MAP: log posterior=190.731, log likelihood=176.377, log prior=14.354, sigma=0.669, l_c=1.71
# step 30500/100000
#   chain acceptance: b=0:0.24 b=0.02:0.22 b=0.05:0.18 b=0.1:0.16 b=0.2:0.16 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.15 2-3:0.54 3-4:0.56 4-5:0.42 5-6:0.44 6-7:0.64
#   cold current: log posterior=185.692, log likelihood=176.323, log prior=9.369, sigma=0.452, l_c=1.24
#   MAP: log posterior=190.731, log likelihood=176.377, log prior=14.354, sigma=0.669, l_c=1.71
# step 31000/100000
#   chain acceptance: b=0:0.23 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.16 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.14 2-3:0.55 3-4:0.56 4-5:0.42 5-6:0.44 6-7:0.64
#   cold current: log posterior=186.665, log likelihood=177.556, log prior=9.109, sigma=4.51, l_c=2.41
#   MAP: log posterior=190.813, log likelihood=177.481, log prior=13.332, sigma=1.36, l_c=2.31
# step 31500/100000
#   chain acceptance: b=0:0.23 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.16 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.14 2-3:0.55 3-4:0.56 4-5:0.43 5-6:0.43 6-7:0.64
#   cold current: log posterior=186.931, log likelihood=176.574, log prior=10.357, sigma=1.56, l_c=1.94
#   MAP: log posterior=190.813, log likelihood=177.481, log prior=13.332, sigma=1.36, l_c=2.31
# step 32000/100000
#   chain acceptance: b=0:0.23 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.14 2-3:0.56 3-4:0.56 4-5:0.43 5-6:0.43 6-7:0.65
#   cold current: log posterior=189.150, log likelihood=177.805, log prior=11.345, sigma=1.45, l_c=1.79
#   MAP: log posterior=190.813, log likelihood=177.481, log prior=13.332, sigma=1.36, l_c=2.31
# step 32500/100000
#   chain acceptance: b=0:0.23 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.14 2-3:0.56 3-4:0.57 4-5:0.43 5-6:0.42 6-7:0.65
#   cold current: log posterior=186.929, log likelihood=176.286, log prior=10.643, sigma=1.79, l_c=2.14
#   MAP: log posterior=190.813, log likelihood=177.481, log prior=13.332, sigma=1.36, l_c=2.31
# step 33000/100000
#   chain acceptance: b=0:0.23 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.14 2-3:0.56 3-4:0.57 4-5:0.44 5-6:0.42 6-7:0.65
#   cold current: log posterior=187.147, log likelihood=177.571, log prior=9.577, sigma=1.47, l_c=1.66
#   MAP: log posterior=190.813, log likelihood=177.481, log prior=13.332, sigma=1.36, l_c=2.31
# step 33500/100000
#   chain acceptance: b=0:0.23 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.14 2-3:0.56 3-4:0.57 4-5:0.44 5-6:0.41 6-7:0.65
#   cold current: log posterior=189.959, log likelihood=177.553, log prior=12.406, sigma=1.41, l_c=2.02
#   MAP: log posterior=190.813, log likelihood=177.481, log prior=13.332, sigma=1.36, l_c=2.31
# step 34000/100000
#   chain acceptance: b=0:0.23 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.14 2-3:0.57 3-4:0.57 4-5:0.44 5-6:0.41 6-7:0.65
#   cold current: log posterior=187.635, log likelihood=177.533, log prior=10.102, sigma=4.02, l_c=3.17
#   MAP: log posterior=190.813, log likelihood=177.481, log prior=13.332, sigma=1.36, l_c=2.31
# step 34500/100000
#   chain acceptance: b=0:0.23 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.58 4-5:0.44 5-6:0.40 6-7:0.65
#   cold current: log posterior=187.246, log likelihood=177.845, log prior=9.401, sigma=1.16, l_c=2.14
#   MAP: log posterior=190.813, log likelihood=177.481, log prior=13.332, sigma=1.36, l_c=2.31
# step 35000/100000
#   chain acceptance: b=0:0.23 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.58 4-5:0.45 5-6:0.40 6-7:0.66
#   cold current: log posterior=189.320, log likelihood=177.861, log prior=11.459, sigma=4.7, l_c=2.91
#   MAP: log posterior=190.813, log likelihood=177.481, log prior=13.332, sigma=1.36, l_c=2.31
# step 35500/100000
#   chain acceptance: b=0:0.23 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.58 4-5:0.45 5-6:0.39 6-7:0.66
#   cold current: log posterior=187.350, log likelihood=176.464, log prior=10.885, sigma=0.892, l_c=1.42
#   MAP: log posterior=190.813, log likelihood=177.481, log prior=13.332, sigma=1.36, l_c=2.31
# step 36000/100000
#   chain acceptance: b=0:0.23 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.58 4-5:0.45 5-6:0.39 6-7:0.66
#   cold current: log posterior=188.092, log likelihood=176.420, log prior=11.672, sigma=0.76, l_c=1.49
#   MAP: log posterior=190.813, log likelihood=177.481, log prior=13.332, sigma=1.36, l_c=2.31
# step 36500/100000
#   chain acceptance: b=0:0.23 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.58 4-5:0.45 5-6:0.38 6-7:0.66
#   cold current: log posterior=186.806, log likelihood=176.255, log prior=10.551, sigma=1.28, l_c=1.82
#   MAP: log posterior=190.813, log likelihood=177.481, log prior=13.332, sigma=1.36, l_c=2.31
# step 37000/100000
#   chain acceptance: b=0:0.23 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.58 4-5:0.45 5-6:0.38 6-7:0.66
#   cold current: log posterior=190.572, log likelihood=177.954, log prior=12.618, sigma=1.94, l_c=2.46
#   MAP: log posterior=190.813, log likelihood=177.481, log prior=13.332, sigma=1.36, l_c=2.31
# step 37500/100000
#   chain acceptance: b=0:0.23 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.58 4-5:0.46 5-6:0.37 6-7:0.66
#   cold current: log posterior=189.836, log likelihood=177.983, log prior=11.854, sigma=1.51, l_c=2.12
#   MAP: log posterior=190.850, log likelihood=177.957, log prior=12.893, sigma=1.71, l_c=2.29
# step 38000/100000
#   chain acceptance: b=0:0.23 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.57 4-5:0.46 5-6:0.37 6-7:0.66
#   cold current: log posterior=179.756, log likelihood=176.244, log prior=3.511, sigma=0.79, l_c=0.954
#   MAP: log posterior=190.850, log likelihood=177.957, log prior=12.893, sigma=1.71, l_c=2.29
# step 38500/100000
#   chain acceptance: b=0:0.23 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.58 4-5:0.46 5-6:0.37 6-7:0.66
#   cold current: log posterior=186.718, log likelihood=177.967, log prior=8.752, sigma=2.38, l_c=2.58
#   MAP: log posterior=190.850, log likelihood=177.957, log prior=12.893, sigma=1.71, l_c=2.29
# step 39000/100000
#   chain acceptance: b=0:0.23 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.58 3-4:0.58 4-5:0.46 5-6:0.36 6-7:0.65
#   cold current: log posterior=184.494, log likelihood=178.082, log prior=6.412, sigma=3.68, l_c=2.57
#   MAP: log posterior=190.850, log likelihood=177.957, log prior=12.893, sigma=1.71, l_c=2.29
# step 39500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.58 4-5:0.46 5-6:0.36 6-7:0.65
#   cold current: log posterior=185.713, log likelihood=176.870, log prior=8.843, sigma=2.87, l_c=2.37
#   MAP: log posterior=190.850, log likelihood=177.957, log prior=12.893, sigma=1.71, l_c=2.29
# step 40000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.58 4-5:0.47 5-6:0.36 6-7:0.66
#   cold current: log posterior=185.992, log likelihood=176.909, log prior=9.083, sigma=2.63, l_c=2.4
#   MAP: log posterior=190.850, log likelihood=177.957, log prior=12.893, sigma=1.71, l_c=2.29
# step 40500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.58 4-5:0.47 5-6:0.36 6-7:0.66
#   cold current: log posterior=185.358, log likelihood=178.655, log prior=6.703, sigma=1.69, l_c=1.71
#   MAP: log posterior=190.850, log likelihood=177.957, log prior=12.893, sigma=1.71, l_c=2.29
# step 41000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.58 4-5:0.47 5-6:0.35 6-7:0.66
#   cold current: log posterior=190.223, log likelihood=178.084, log prior=12.139, sigma=1.49, l_c=2.12
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 41500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.58 4-5:0.47 5-6:0.35 6-7:0.66
#   cold current: log posterior=189.165, log likelihood=177.629, log prior=11.536, sigma=2.76, l_c=2.67
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 42000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.58 4-5:0.48 5-6:0.34 6-7:0.66
#   cold current: log posterior=185.713, log likelihood=178.717, log prior=6.996, sigma=2.57, l_c=1.9
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 42500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.59 4-5:0.48 5-6:0.34 6-7:0.67
#   cold current: log posterior=183.494, log likelihood=177.777, log prior=5.717, sigma=2.08, l_c=1.48
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 43000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.57 3-4:0.59 4-5:0.48 5-6:0.34 6-7:0.67
#   cold current: log posterior=188.927, log likelihood=177.968, log prior=10.959, sigma=1.38, l_c=2.26
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 43500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.58 3-4:0.59 4-5:0.48 5-6:0.34 6-7:0.67
#   cold current: log posterior=184.350, log likelihood=178.560, log prior=5.791, sigma=0.934, l_c=1.23
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 44000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.22 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.58 3-4:0.59 4-5:0.48 5-6:0.34 6-7:0.67
#   cold current: log posterior=189.086, log likelihood=177.968, log prior=11.119, sigma=3.76, l_c=2.52
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 44500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.13 2-3:0.58 3-4:0.60 4-5:0.48 5-6:0.33 6-7:0.68
#   cold current: log posterior=188.885, log likelihood=177.980, log prior=10.905, sigma=3.91, l_c=2.58
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 45000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.14 2-3:0.58 3-4:0.60 4-5:0.48 5-6:0.33 6-7:0.68
#   cold current: log posterior=177.997, log likelihood=175.167, log prior=2.829, sigma=0.813, l_c=1
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 45500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.15 2-3:0.58 3-4:0.60 4-5:0.48 5-6:0.34 6-7:0.68
#   cold current: log posterior=189.409, log likelihood=177.984, log prior=11.425, sigma=1.5, l_c=2.34
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 46000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.15 2-3:0.58 3-4:0.60 4-5:0.47 5-6:0.34 6-7:0.68
#   cold current: log posterior=183.500, log likelihood=178.059, log prior=5.441, sigma=0.794, l_c=1.2
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 46500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.16 2-3:0.58 3-4:0.60 4-5:0.47 5-6:0.34 6-7:0.68
#   cold current: log posterior=185.877, log likelihood=178.114, log prior=7.763, sigma=1.27, l_c=1.57
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 47000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.16 2-3:0.58 3-4:0.60 4-5:0.47 5-6:0.35 6-7:0.69
#   cold current: log posterior=179.557, log likelihood=176.905, log prior=2.652, sigma=1.72, l_c=1.39
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 47500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.17 2-3:0.59 3-4:0.60 4-5:0.46 5-6:0.35 6-7:0.69
#   cold current: log posterior=185.232, log likelihood=178.133, log prior=7.099, sigma=1.35, l_c=1.4
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 48000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.17 2-3:0.59 3-4:0.60 4-5:0.46 5-6:0.36 6-7:0.69
#   cold current: log posterior=184.194, log likelihood=178.181, log prior=6.013, sigma=0.573, l_c=1.39
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 48500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.18 2-3:0.59 3-4:0.61 4-5:0.46 5-6:0.36 6-7:0.69
#   cold current: log posterior=185.006, log likelihood=178.162, log prior=6.845, sigma=2.79, l_c=1.9
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 49000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.18 2-3:0.59 3-4:0.61 4-5:0.46 5-6:0.36 6-7:0.69
#   cold current: log posterior=186.166, log likelihood=177.924, log prior=8.242, sigma=0.993, l_c=1.35
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 49500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.19 2-3:0.60 3-4:0.61 4-5:0.45 5-6:0.37 6-7:0.70
#   cold current: log posterior=182.008, log likelihood=178.035, log prior=3.973, sigma=1.38, l_c=1.64
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 50000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.19 2-3:0.60 3-4:0.61 4-5:0.45 5-6:0.37 6-7:0.70
#   cold current: log posterior=183.880, log likelihood=176.891, log prior=6.989, sigma=2.83, l_c=1.78
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 50500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.20 2-3:0.60 3-4:0.61 4-5:0.45 5-6:0.37 6-7:0.70
#   cold current: log posterior=183.544, log likelihood=178.086, log prior=5.458, sigma=1.67, l_c=1.28
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 51000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.21 2-3:0.60 3-4:0.61 4-5:0.45 5-6:0.38 6-7:0.70
#   cold current: log posterior=185.369, log likelihood=178.298, log prior=7.071, sigma=2.85, l_c=1.84
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 51500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.21 2-3:0.61 3-4:0.62 4-5:0.45 5-6:0.38 6-7:0.70
#   cold current: log posterior=184.109, log likelihood=178.176, log prior=5.933, sigma=2.59, l_c=1.76
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 52000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.21 2-3:0.61 3-4:0.61 4-5:0.45 5-6:0.38 6-7:0.70
#   cold current: log posterior=185.683, log likelihood=178.160, log prior=7.524, sigma=2.49, l_c=1.86
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 52500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.22 2-3:0.61 3-4:0.61 4-5:0.45 5-6:0.38 6-7:0.70
#   cold current: log posterior=182.274, log likelihood=178.096, log prior=4.178, sigma=0.768, l_c=1.47
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 53000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.17 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.22 2-3:0.61 3-4:0.61 4-5:0.45 5-6:0.38 6-7:0.70
#   cold current: log posterior=187.887, log likelihood=178.125, log prior=9.761, sigma=2.01, l_c=1.94
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 53500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.22 2-3:0.61 3-4:0.62 4-5:0.45 5-6:0.38 6-7:0.70
#   cold current: log posterior=184.135, log likelihood=176.191, log prior=7.944, sigma=1.89, l_c=1.76
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 54000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.22 2-3:0.61 3-4:0.62 4-5:0.46 5-6:0.38 6-7:0.70
#   cold current: log posterior=184.828, log likelihood=178.126, log prior=6.702, sigma=2.97, l_c=1.82
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 54500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.22 2-3:0.61 3-4:0.62 4-5:0.46 5-6:0.38 6-7:0.70
#   cold current: log posterior=186.438, log likelihood=176.618, log prior=9.820, sigma=2.01, l_c=2.12
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 55000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.22 2-3:0.62 3-4:0.62 4-5:0.46 5-6:0.38 6-7:0.70
#   cold current: log posterior=188.815, log likelihood=177.607, log prior=11.208, sigma=1.35, l_c=1.8
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 55500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.21 2-3:0.62 3-4:0.62 4-5:0.46 5-6:0.37 6-7:0.71
#   cold current: log posterior=187.004, log likelihood=177.884, log prior=9.120, sigma=2.69, l_c=1.89
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 56000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.21 2-3:0.62 3-4:0.62 4-5:0.46 5-6:0.37 6-7:0.71
#   cold current: log posterior=186.362, log likelihood=177.992, log prior=8.370, sigma=4.86, l_c=2.76
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 56500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.21 2-3:0.62 3-4:0.62 4-5:0.46 5-6:0.37 6-7:0.71
#   cold current: log posterior=187.436, log likelihood=177.921, log prior=9.515, sigma=2.55, l_c=2.09
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 57000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.21 2-3:0.63 3-4:0.63 4-5:0.46 5-6:0.37 6-7:0.71
#   cold current: log posterior=188.427, log likelihood=177.931, log prior=10.496, sigma=2.01, l_c=2.05
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 57500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.21 2-3:0.63 3-4:0.63 4-5:0.46 5-6:0.37 6-7:0.71
#   cold current: log posterior=187.479, log likelihood=177.999, log prior=9.480, sigma=0.769, l_c=1.47
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 58000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.20 2-3:0.62 3-4:0.62 4-5:0.46 5-6:0.36 6-7:0.71
#   cold current: log posterior=186.315, log likelihood=177.939, log prior=8.376, sigma=0.785, l_c=1.37
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 58500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.20 2-3:0.62 3-4:0.62 4-5:0.46 5-6:0.36 6-7:0.71
#   cold current: log posterior=186.953, log likelihood=178.016, log prior=8.937, sigma=0.814, l_c=1.55
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 59000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.20 2-3:0.62 3-4:0.62 4-5:0.46 5-6:0.36 6-7:0.71
#   cold current: log posterior=180.667, log likelihood=176.445, log prior=4.222, sigma=1.36, l_c=1.18
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 59500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.20 2-3:0.62 3-4:0.62 4-5:0.46 5-6:0.36 6-7:0.71
#   cold current: log posterior=178.254, log likelihood=177.696, log prior=0.559, sigma=3.91, l_c=1.35
#   MAP: log posterior=190.854, log likelihood=178.070, log prior=12.784, sigma=1.39, l_c=2.09
# step 60000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.16 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.00 1-2:0.20 2-3:0.62 3-4:0.62 4-5:0.46 5-6:0.36 6-7:0.71
#   cold current: log posterior=187.516, log likelihood=177.996, log prior=9.520, sigma=1.18, l_c=1.47
# ...
#   cold current: log posterior=187.909, log likelihood=178.538, log prior=9.372, sigma=0.814, l_c=1.36
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 81500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.17 2-3:0.61 3-4:0.62 4-5:0.49 5-6:0.35 6-7:0.71
#   cold current: log posterior=191.360, log likelihood=177.377, log prior=13.983, sigma=0.753, l_c=1.72
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 82000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.17 2-3:0.61 3-4:0.62 4-5:0.49 5-6:0.35 6-7:0.71
#   cold current: log posterior=185.360, log likelihood=178.111, log prior=7.248, sigma=0.492, l_c=1.24
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 82500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.16 2-3:0.61 3-4:0.62 4-5:0.49 5-6:0.35 6-7:0.71
#   cold current: log posterior=180.013, log likelihood=176.586, log prior=3.427, sigma=0.49, l_c=1.05
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 83000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.16 2-3:0.61 3-4:0.62 4-5:0.49 5-6:0.35 6-7:0.71
#   cold current: log posterior=182.709, log likelihood=178.184, log prior=4.525, sigma=1.5, l_c=1.18
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 83500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.16 2-3:0.60 3-4:0.62 4-5:0.49 5-6:0.35 6-7:0.71
#   cold current: log posterior=185.083, log likelihood=177.808, log prior=7.275, sigma=1.19, l_c=1.35
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 84000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.16 2-3:0.60 3-4:0.62 4-5:0.49 5-6:0.36 6-7:0.71
#   cold current: log posterior=189.040, log likelihood=176.823, log prior=12.217, sigma=0.916, l_c=1.63
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 84500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.16 2-3:0.60 3-4:0.62 4-5:0.49 5-6:0.36 6-7:0.71
#   cold current: log posterior=189.442, log likelihood=176.831, log prior=12.611, sigma=0.82, l_c=1.67
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 85000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.16 2-3:0.60 3-4:0.62 4-5:0.49 5-6:0.36 6-7:0.71
#   cold current: log posterior=189.577, log likelihood=176.386, log prior=13.192, sigma=4.23, l_c=3.39
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 85500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.16 2-3:0.60 3-4:0.62 4-5:0.49 5-6:0.36 6-7:0.71
#   cold current: log posterior=185.582, log likelihood=173.903, log prior=11.680, sigma=1.65, l_c=1.94
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 86000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.16 2-3:0.60 3-4:0.62 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=188.887, log likelihood=177.455, log prior=11.432, sigma=1.57, l_c=1.95
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 86500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.16 2-3:0.61 3-4:0.62 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=189.044, log likelihood=176.360, log prior=12.684, sigma=4.16, l_c=2.91
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 87000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.16 2-3:0.61 3-4:0.62 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=185.734, log likelihood=177.549, log prior=8.185, sigma=2.91, l_c=2.35
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 87500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.16 2-3:0.61 3-4:0.62 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=186.284, log likelihood=176.643, log prior=9.640, sigma=2.08, l_c=2.25
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 88000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.61 3-4:0.62 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=187.988, log likelihood=176.675, log prior=11.313, sigma=1.14, l_c=1.74
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 88500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.61 3-4:0.62 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=191.303, log likelihood=175.819, log prior=15.485, sigma=1.51, l_c=2.57
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 89000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.61 3-4:0.62 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=185.547, log likelihood=177.925, log prior=7.622, sigma=3.29, l_c=2.32
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 89500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.61 3-4:0.62 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=188.546, log likelihood=177.511, log prior=11.035, sigma=4.06, l_c=3.83
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 90000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.61 3-4:0.62 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=188.405, log likelihood=177.930, log prior=10.475, sigma=2.24, l_c=2.05
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 90500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.62 3-4:0.62 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=184.526, log likelihood=177.813, log prior=6.713, sigma=1.98, l_c=1.46
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 91000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.62 3-4:0.62 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=182.993, log likelihood=173.407, log prior=9.585, sigma=3.84, l_c=2.7
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 91500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.62 3-4:0.62 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=192.164, log likelihood=177.585, log prior=14.579, sigma=1.22, l_c=2.43
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 92000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.62 3-4:0.62 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=191.990, log likelihood=177.586, log prior=14.404, sigma=1.76, l_c=2.56
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 92500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.62 3-4:0.62 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=191.262, log likelihood=177.564, log prior=13.698, sigma=3.45, l_c=2.99
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 93000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.62 3-4:0.62 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=187.713, log likelihood=177.780, log prior=9.934, sigma=3.7, l_c=2.36
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 93500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.62 3-4:0.63 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=189.102, log likelihood=177.036, log prior=12.065, sigma=3.39, l_c=2.44
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 94000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.62 3-4:0.63 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=189.117, log likelihood=177.795, log prior=11.322, sigma=2.05, l_c=2.15
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 94500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.62 3-4:0.63 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=191.599, log likelihood=176.678, log prior=14.920, sigma=1.3, l_c=2.18
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 95000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.62 3-4:0.63 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=185.319, log likelihood=177.815, log prior=7.504, sigma=3.39, l_c=2.09
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 95500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.15 2-3:0.62 3-4:0.63 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=186.896, log likelihood=177.717, log prior=9.179, sigma=1.03, l_c=1.51
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 96000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.14 2-3:0.62 3-4:0.63 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=187.674, log likelihood=177.645, log prior=10.028, sigma=3.1, l_c=2.14
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 96500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.21 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.14 2-3:0.62 3-4:0.63 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=190.595, log likelihood=177.340, log prior=13.255, sigma=1.6, l_c=2.22
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 97000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.14 2-3:0.62 3-4:0.63 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=192.732, log likelihood=177.565, log prior=15.168, sigma=1.22, l_c=2.23
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 97500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.14 2-3:0.62 3-4:0.63 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=191.226, log likelihood=177.556, log prior=13.670, sigma=1.39, l_c=2.06
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 98000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.14 2-3:0.62 3-4:0.63 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=188.421, log likelihood=176.960, log prior=11.461, sigma=3.72, l_c=3.11
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 98500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.14 2-3:0.62 3-4:0.63 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=188.603, log likelihood=176.982, log prior=11.620, sigma=4.69, l_c=3.2
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 99000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.14 2-3:0.62 3-4:0.63 4-5:0.50 5-6:0.36 6-7:0.71
#   cold current: log posterior=190.181, log likelihood=176.080, log prior=14.100, sigma=2.12, l_c=2.51
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 99500/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.14 2-3:0.63 3-4:0.63 4-5:0.51 5-6:0.36 6-7:0.71
#   cold current: log posterior=188.373, log likelihood=175.910, log prior=12.463, sigma=4.57, l_c=3.18
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# step 100000/100000
#   chain acceptance: b=0:0.22 b=0.02:0.20 b=0.05:0.16 b=0.1:0.15 b=0.2:0.15 b=0.4:0.14 b=0.7:0.14 b=1:0.14
#   swap acceptance: 0-1:0.03 1-2:0.14 2-3:0.63 3-4:0.63 4-5:0.51 5-6:0.36 6-7:0.71
#   cold current: log posterior=192.667, log likelihood=177.168, log prior=15.499, sigma=1.43, l_c=2.57
#   MAP: log posterior=193.437, log likelihood=177.423, log prior=16.014, sigma=0.899, l_c=2.18
# done
# saved posterior samples = 19900
# MAP: sigma=0.899124, l_c=2.18378, log posterior=193.437, log likelihood=177.423, log prior=16.014
# final chain acceptance rates:
#   beta=0: 0.218
#   beta=0.02: 0.204
#   beta=0.05: 0.156
#   beta=0.1: 0.149
#   beta=0.2: 0.146
#   beta=0.4: 0.140
#   beta=0.7: 0.142
#   beta=1: 0.139
# final swap acceptance rates:
#   beta 0 <-> 0.02: 0.027
#   beta 0.02 <-> 0.05: 0.140
#   beta 0.05 <-> 0.1: 0.625
#   beta 0.1 <-> 0.2: 0.632
#   beta 0.2 <-> 0.4: 0.505
#   beta 0.4 <-> 0.7: 0.360
#   beta 0.7 <-> 1: 0.713

# %%
E_plot = np.linspace(E_min, E_max, 500)

f_samples_plot = np.array([
    Kinv_gp_values(samples_f[i], samples_sigma[i], samples_lc[i], E_plot)
    for i in np.linspace(0, len(samples_f)-1, min(500, len(samples_f)), dtype=int)
])

f_low, f_med, f_high = np.percentile(f_samples_plot, [16, 50, 84], axis=0)

plt.figure(figsize=(8, 5))
plt.fill_between(E_plot, f_low, f_high, alpha=0.25, label="68% band")
plt.plot(E_plot, f_med, linewidth=2.0, label="posterior median")

best_plot = Kinv_gp_values(best_f, best_sigma, best_lc, E_plot)
plt.plot(E_plot, best_plot, "--", linewidth=2.5, label="best GP sample")
plt.plot(E_plot, Kinv_true(E_plot), linewidth=2.5, label="hidden truth")
plt.scatter(knots, best_f, zorder=5, label="best GP knots")

plt.xlabel(r"$E^*$")
plt.ylabel(r"$K^{-1}(E^*)$")
plt.title(rf"$K^{{-1}}(E^*)$, best sample $\sigma={best_sigma:.3g}$, $\ell_c={best_lc:.3g}$")
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))
plt.scatter(samples_lc, samples_sigma, s=12, alpha=0.35, label="accepted samples")
plt.scatter([best_lc], [best_sigma], marker="*", s=180, label="highest-probability sample")
plt.xlim(lc_min, lc_max)
plt.ylim(sigma_min, sigma_max)
plt.xlabel(r"kernel correlation length $l_c$")
plt.ylabel(r"kernel amplitude $\sigma$")
plt.title(r"Monte Carlo samples for $l_c$ and $\sigma$")
plt.legend()
plt.tight_layout()
plt.show()
#plt.figure(figsize=(8, 4))
#plt.plot(logpost_samples, label="log posterior")
#plt.plot(loglike_samples, label="log likelihood")
#plt.plot(logprior_samples, label="log prior")
#plt.xlabel("saved sample")
#plt.ylabel("log probability")
#plt.title("Posterior trace pieces")
#plt.legend()
#plt.tight_layout()
#plt.show()

# %%
_, _, _, interp_best = gp_matrices(best_sigma, best_lc)

predicted_rows = []
for L in Ls:
    for frame in frame_names:
        for level_index, E_pred in enumerate(predict_levels_from_gp(best_f, interp_best, L, frame)):
            predicted_rows.append({
                "L": float(L),
                "frame": frame,
                "level_index": level_index,
                "E_pred": float(E_pred),
            })

plot_spectrum(
    data,
    "Spectrum reconstruction",
    include_observed=True,
    include_true=False,
    predicted_rows=predicted_rows,
)

# %%
from matplotlib.lines import Line2D

# Rebuild the 2D posterior density from the current MCMC samples.
# This is crucial: do not reuse stale H_plot / LC / lc_edges from an older run.
lc_samples = np.asarray(samples_lc, dtype=float)
sigma_samples = np.asarray(samples_sigma, dtype=float)

print("Current plotting bounds:")
print(f"l_c   range = [{lc_min}, {lc_max}]")
print(f"sigma range = [{sigma_min}, {sigma_max}]")
print()
print("Actual sample ranges:")
print(f"l_c   min/max = {np.min(lc_samples):.6g}, {np.max(lc_samples):.6g}")
print(f"sigma min/max = {np.min(sigma_samples):.6g}, {np.max(sigma_samples):.6g}")

if len(lc_samples) < 5:
    raise ValueError("Need at least a few saved posterior samples before making the contour plot.")

n_bins_lc = 50
n_bins_sigma = 50

H, lc_edges, sigma_edges = np.histogram2d(
    lc_samples,
    sigma_samples,
    bins=(n_bins_lc, n_bins_sigma),
    range=((lc_min, lc_max), (sigma_min, sigma_max)),
    density=True,
)

try:
    from scipy.ndimage import gaussian_filter
    H_plot = gaussian_filter(H, sigma=1.0)
except Exception:
    H_plot = H

lc_centers = 0.5*(lc_edges[:-1] + lc_edges[1:])
sigma_centers = 0.5*(sigma_edges[:-1] + sigma_edges[1:])
LC, SIGMA = np.meshgrid(lc_centers, sigma_centers, indexing="ij")


def hpd_density_level(H_density, x_edges, y_edges, mass):
    dx = np.diff(x_edges)[:, None]
    dy = np.diff(y_edges)[None, :]
    cell_mass = H_density*dx*dy

    order = np.argsort(H_density.ravel())[::-1]
    sorted_density = H_density.ravel()[order]
    sorted_mass = cell_mass.ravel()[order]

    cumulative_mass = np.cumsum(sorted_mass)
    cumulative_mass /= cumulative_mass[-1]

    idx = np.searchsorted(cumulative_mass, mass)
    idx = min(idx, len(sorted_density) - 1)

    return sorted_density[idx]


plt.figure(figsize=(7, 5.5))
ax = plt.gca()
ax.set_facecolor("white")

# HPD contours at 20%, 40%, 60%, 80%.
# Here 20% is the innermost/highest-density contour.
masses = [0.20, 0.40, 0.60, 0.80]
levels = [hpd_density_level(H_plot, lc_edges, sigma_edges, m) for m in masses]

# Matplotlib needs increasing density levels.
level_mass_pairs = sorted(zip(levels, masses), key=lambda x: x[0])
contour_levels = [x[0] for x in level_mass_pairs]
contour_masses = [x[1] for x in level_mass_pairs]

# Reverse thickness convention:
# thickest = 20%, thinnest = 80%.
linewidth_map = {
    0.20: 3.0,
    0.40: 2.3,
    0.60: 1.6,
    0.80: 0.9,
}
linewidths = [linewidth_map[m] for m in contour_masses]

plt.contour(
    LC,
    SIGMA,
    H_plot,
    levels=contour_levels,
    colors="C1",
    linewidths=linewidths,
)

# Posterior sample cloud
plt.scatter(
    lc_samples,
    sigma_samples,
    s=5,
    alpha=0.12,
    color="black",
)

# 2D marginal mode from the same density used for the contours
imax, jmax = np.unravel_index(np.argmax(H_plot), H_plot.shape)
mode_lc_2d = lc_centers[imax]
mode_sigma_2d = sigma_centers[jmax]

print()
print("2D marginal posterior mode:")
print(f"l_c   = {mode_lc_2d:.6g}")
print(f"sigma = {mode_sigma_2d:.6g}")

print()
print("Best sample coordinates:")
print(f"l_c   = {best_lc:.6g}")
print(f"sigma = {best_sigma:.6g}")

# Blue plus: peak of the marginalized (l_c, sigma) density
plt.scatter(
    [mode_lc_2d],
    [mode_sigma_2d],
    marker="+",
    s=260,
    color="C0",
    linewidths=4,
    zorder=12,
)

# Red cross: best sample
plt.scatter(
    [best_lc],
    [best_sigma],
    marker="x",
    s=220,
    color="red",
    linewidths=3.5,
    zorder=13,
)

plt.xlim(lc_min, lc_max)
plt.ylim(sigma_min, sigma_max)
plt.xlabel(r"$\ell_c$")
plt.ylabel(r"$\sigma$")

legend_handles = [
    Line2D([0], [0], color="C1", lw=3.0, label="20%"),
    Line2D([0], [0], color="C1", lw=2.3, label="40%"),
    Line2D([0], [0], color="C1", lw=1.6, label="60%"),
    Line2D([0], [0], color="C1", lw=0.9, label="80%"),
    Line2D(
        [0], [0],
        marker="o",
        linestyle="None",
        color="black",
        markersize=5,
        alpha=0.5,
        label="Samples",
    ),
    Line2D(
        [0], [0],
        marker="+",
        linestyle="None",
        color="C0",
        markersize=12,
        markeredgewidth=3,
        label=r"Marginal peak in $(\ell_c,\sigma)$",
    ),
    Line2D(
        [0], [0],
        marker="x",
        linestyle="None",
        color="red",
        markersize=11,
        markeredgewidth=3,
        label="Best sample",
    ),
]

plt.legend(handles=legend_handles, loc="best")
plt.tight_layout()
plt.show()

# %%
# ============================================================
# Final Bayesian model-averaged posterior predictive plot
# ============================================================

# This cell uses the saved beta=1 samples:
#   samples_f, samples_sigma, samples_lc
#
# Each saved MCMC sample is one draw from
#
#   p(f_knots, sigma, l_c | finite-volume spectrum).
#
# Therefore the posterior predictive distribution for K^{-1}(E*)
# is approximated by evaluating K^{-1}(E*) for every saved sample.

E_plot = np.linspace(E_min, E_max, 500)

if len(samples_f) == 0:
    raise ValueError("No posterior samples found. Run the MCMC cell first.")

# Evaluate K^{-1}(E*) for every posterior sample.
# Shape: (n_samples, len(E_plot))
Kinv_posterior_samples = np.array([
    Kinv_gp_values(f, sigma, l_c, E_plot)
    for f, sigma, l_c in zip(samples_f, samples_sigma, samples_lc)
])

# Bayesian model-averaged central curve.
# This is the posterior mean:
#
#   E[K^{-1}(E*) | data]
#
Kinv_mean = np.mean(Kinv_posterior_samples, axis=0)

# Pointwise posterior credible bands.
Kinv_low_68, Kinv_med, Kinv_high_68 = np.percentile(
    Kinv_posterior_samples,
    [16, 50, 84],
    axis=0,
)

Kinv_low_95, Kinv_high_95 = np.percentile(
    Kinv_posterior_samples,
    [2.5, 97.5],
    axis=0,
)

plt.figure(figsize=(8, 5))

plt.fill_between(
    E_plot,
    Kinv_low_95,
    Kinv_high_95,
    alpha=0.15,
    label="95% posterior band",
)

plt.fill_between(
    E_plot,
    Kinv_low_68,
    Kinv_high_68,
    alpha=0.30,
    label="68% posterior band",
)

plt.plot(
    E_plot,
    Kinv_mean,
    linewidth=2.5,
    label=r"posterior mean / model average",
)

plt.plot(
    E_plot,
    Kinv_med,
    "--",
    linewidth=2.0,
    label=r"posterior median",
)

# Only include this because this is mock data and we know the hidden answer.
plt.plot(
    E_plot,
    Kinv_true(E_plot),
    linewidth=2.5,
    label="hidden truth",
)

plt.xlabel(r"$E^*$")
plt.ylabel(r"$K^{-1}(E^*)$")
plt.title(r"Bayesian posterior predictive distribution for $K^{-1}(E^*)$")
plt.legend()
plt.tight_layout()
plt.show()


# ============================================================
# Print Bayesian summary of the hyperparameters
# ============================================================

sigma_mean = np.mean(samples_sigma)
sigma_low, sigma_med, sigma_high = np.percentile(samples_sigma, [16, 50, 84])

lc_mean = np.mean(samples_lc)
lc_low, lc_med, lc_high = np.percentile(samples_lc, [16, 50, 84])

#print("Bayesian posterior summary")
#print("--------------------------")
#print(f"number of posterior samples = {len(samples_f)}")
#print()
##print(f"sigma posterior mean  = {sigma_mean:.6g}")
#print(f"sigma posterior median = {sigma_med:.6g}")
#print(f"sigma 68% interval     = [{sigma_low:.6g}, {sigma_high:.6g}]")
#print()
#print(f"l_c posterior mean     = {lc_mean:.6g}")
#print(f"l_c posterior median   = {lc_med:.6g}")
#print(f"l_c 68% interval       = [{lc_low:.6g}, {lc_high:.6g}]")

# %%
# ============================================================
# Optional: show a few posterior draws, not as the answer,
# but as a visual reminder that the band comes from many curves.
# ============================================================

n_draws_to_show = min(40, len(samples_f))
draw_ids = rng.choice(len(samples_f), size=n_draws_to_show, replace=False)

plt.figure(figsize=(8, 5))

for i in draw_ids:
    plt.plot(
        E_plot,
        Kinv_posterior_samples[i],
        alpha=0.12,
        linewidth=1.0,
    )

plt.plot(
    E_plot,
    Kinv_mean,
    linewidth=3.0,
    label=r"posterior mean / model average",
)

plt.fill_between(
    E_plot,
    Kinv_low_68,
    Kinv_high_68,
    alpha=0.25,
    label="68% posterior band",
)

#plt.plot(
#    E_plot,
#    Kinv_true(E_plot),
#    linewidth=2.5,
#    label="hidden truth",
#)

#plt.xlabel(r"$E^*$")
#plt.ylabel(r"$K^{-1}(E^*)$")
#plt.title(r"Posterior samples contributing to the Bayesian model average")
#plt.legend()
#plt.tight_layout()
plt.show()

# %%
print(rng)

# %%
rng = np.random.default_rng(1234)

print(rng.bit_generator.state)

# %%
saved_state = rng.bit_generator.state

# %%
rng2 = np.random.default_rng()
rng2.bit_generator.state = saved_state

# %%
import json

rng_state = rng.bit_generator.state

with open("rng_state.json", "w") as f:
    json.dump(rng_state, f)

# %%
# ============================================================
# Plot the sample closest to the 2D marginal posterior mode
# with the same bells and whistles as the best sample
# ============================================================

if len(samples_f) == 0:
    raise ValueError("No posterior samples found. Run the MCMC cell first.")

# The contour cell defines these:
#   mode_lc_2d
#   mode_sigma_2d
#
# Now choose the actual saved MCMC sample closest to that 2D marginal peak.
# Use fractional distance so l_c and sigma are weighted comparably.
dist_to_mode = (
    ((samples_lc - mode_lc_2d)/(lc_max - lc_min))**2
    +
    ((samples_sigma - mode_sigma_2d)/(sigma_max - sigma_min))**2
)

mode_index = int(np.argmin(dist_to_mode))

mode_f = samples_f[mode_index]
mode_sigma = samples_sigma[mode_index]
mode_lc = samples_lc[mode_index]
mode_logpost = logpost_samples[mode_index]
mode_loglike = loglike_samples[mode_index]
mode_logprior = logprior_samples[mode_index]

print("Sample closest to 2D marginal posterior mode")
print("index =", mode_index)
print(f"sigma = {mode_sigma:.6g}")
print(f"l_c   = {mode_lc:.6g}")
print(f"log posterior  = {mode_logpost:.3f}")
print(f"log likelihood = {mode_loglike:.3f}")
print(f"log prior      = {mode_logprior:.3f}")
print()
print("2D marginal peak coordinates")
print(f"sigma = {mode_sigma_2d:.6g}")
print(f"l_c   = {mode_lc_2d:.6g}")


# ============================================================
# K^{-1}(E*) plot for marginal-mode sample
# ============================================================

E_plot = np.linspace(E_min, E_max, 500)

Kinv_mode = Kinv_gp_values(mode_f, mode_sigma, mode_lc, E_plot)

plt.figure(figsize=(8, 5))

# Use the existing posterior band if it has already been computed.
try:
    plt.fill_between(
        E_plot,
        Kinv_low_68,
        Kinv_high_68,
        alpha=0.25,
        label="68% posterior band",
    )
    plt.plot(
        E_plot,
        Kinv_mean,
        linewidth=2.5,
        label="posterior mean / model average",
    )
except NameError:
    pass

plt.plot(
    E_plot,
    Kinv_mode,
    "--",
    linewidth=2.5,
    label="marginal-mode GP sample",
)

plt.plot(
    E_plot,
    Kinv_true(E_plot),
    linewidth=2.5,
    label="hidden truth",
)

plt.scatter(
    knots,
    mode_f,
    zorder=5,
    label="marginal-mode GP knots",
)

plt.xlabel(r"$E^*$")
plt.ylabel(r"$K^{-1}(E^*)$")
plt.title(
    rf"$K^{{-1}}(E^*)$, marginal-mode sample "
    rf"$\sigma={mode_sigma:.3g}$, $\ell_c={mode_lc:.3g}$"
)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# ============================================================
# Finite-volume spectrum from marginal-mode sample
# ============================================================

_, _, _, interp_mode = gp_matrices(mode_sigma, mode_lc)

predicted_rows_mode = []

for L in Ls:
    for frame in frame_names:
        for level_index, E_pred in enumerate(
            predict_levels_from_gp(mode_f, interp_mode, L, frame)
        ):
            predicted_rows_mode.append({
                "L": float(L),
                "frame": frame,
                "level_index": level_index,
                "E_pred": float(E_pred),
            })

plot_spectrum(
    data,
    "Spectrum reconstruction: marginal-mode sample",
    include_observed=True,
    include_true=False,
    predicted_rows=predicted_rows_mode,
)

# %%
# ============================================================
# Spectrum reconstruction from the model-averaged GP fit
# ============================================================

if len(samples_f) == 0:
    raise ValueError("No posterior samples found. Run the MCMC cell first.")

# Evaluate every posterior sample on the same E_grid used for root finding.
# Shape: (n_samples, len(E_grid))
Kinv_grid_samples = np.array([
    Kinv_gp_values(f, sigma, l_c, E_grid)
    for f, sigma, l_c in zip(samples_f, samples_sigma, samples_lc)
])

# Bayesian model-averaged K^{-1}(E*) on the root-finding grid.
Kinv_grid_model_avg = np.mean(Kinv_grid_samples, axis=0)

predicted_rows_model_avg = []

for L in Ls:
    for frame in frame_names:

        # Quantization condition using the model-averaged K^{-1}
        QC_model_avg = Kinv_grid_model_avg + F_grids[(float(L), frame)]

        levels_model_avg = roots_from_grid(QC_model_avg, L, frame)

        for level_index, E_pred in enumerate(levels_model_avg):
            predicted_rows_model_avg.append({
                "L": float(L),
                "frame": frame,
                "level_index": level_index,
                "E_pred": float(E_pred),
            })

plot_spectrum(
    data,
    "Spectrum reconstruction: model-averaged GP fit",
    include_observed=True,
    include_true=False,
    predicted_rows=predicted_rows_model_avg,
)
